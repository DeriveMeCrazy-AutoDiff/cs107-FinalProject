# %% [markdown]
# ## Requirements for Milestone 2
# - Working forward mode implementation (not required to support multiple functions of multiple inputs yet)
# - Updated / extended documentation
# - Test Suite
# - Proposal for additional feature(s)

# %% [markdown]
# ### Milestone 2 Progress Timeline
# - Sunday, 15 November 2020: Progress Update/Discuss Implementation Concerns
# - Tuesday 17 November 2020: Individual Task Completion/Integration Testing
# - Thursday 19 November 2020: Milestone 2 Submission

# %% [markdown]
# #### Milestone 2 assignments per group member:
# - Moriya Dechtiar:
#     - Implement ad_trace_elem class
# - John Alling:
#     - Implement class to parse function from input string
# - Al-Muataz Khalil
#     - Implementation of ad_trace class.
# - Benjamin Liu
#     - Implement op_type and operand class

# %% [markdown]
# #### Progress since M1 per group member:
#
# - Moriya Dechtiar:
#
#     - Reviewed TF's feedback for Milestone 1
#     - Worked on apllying the feedback comments on our M1 implementation section.
#     - Continued high level design of our solution implementation
#
# - John Alling:
#     - Researched Backpropagation algorithm for future extension
#     - Reviewed Milestone 1 feedback
#
# - Al-Muataz Khalil
#     - Reviewed Milestone 1 feedback
#     - Added Graph as response to TF feedback
#     - Brainstormed ad_trace implemtation
#
#
# - Benjamin Liu
#     - Reviewed Milestone 1 feedback
#     - Researched on backpropagation
#     - Brainstormed the implementations of the class I'm in charge of
